# %% [markdown]
# # Setup notebook

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Cloning the repository
link = 'https://github.com/PaulOkwija/needle_segmentation.git'
# !git clone $link
# Out:
# Cloning into 'needle_segmentation'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 129 (delta 24), reused 112 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (129/129), 34.34 MiB | 22.17 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
# %cd /content/needle_segmentation
# !python src/obtain_image_data.py --data_path '/content/drive/My Drive/Needle work/Data/data_4_code_line'
# %cd /content
# Out:
# /content/needle_segmentation
# ../data/raw/data_4_code_line directory created
# Copying image files...
# alvin_line_labels.csv copied
# alvin_line_labels_03_2022.csv copied
# sylvia_line_labels.csv copied
# joan_line_labels.csv copied
# paul_line_labels.csv copied
# Paul_line_labels_03_2022.csv copied
# chicken_porcine_line_data.csv copied
# 2363 images extracted
# Images copied and extracted to: ../data/raw
# Done!

# %%
# !pip install -q wandb

# %% [markdown]
# # Importing all necessary libraries

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'needle_segmentation/requirements.txt'

# %%
# !python src/train_pytorch.py --arch "UNet" -sd '/content/needle_segmentation/saved_models' --batch_size 8 --ep 5 -sz 256 --name 'UNet_orig'
# Out:
# 2025-03-26 19:26:39.389635: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743017199.410016   10731 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743017199.416521   10731 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-26 19:26:39.437025: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# %cd needle-work/src
model = "UNeXt_s_0.pth"
saved_models = "saved_models"
model_path = f"{saved_models}/{model}"
# !python src/test_model.py --arch "UNeXt_s" --batch_size 1 --model_dir {model_path}
# Out:
# 2025-03-26 19:07:57.275005: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743016077.295793    5630 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743016077.302012    5630 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-26 19:07:57.322720: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
